# %% [markdown]
# # Test two color functionality

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import logging

import numpy as np
import pandas as pd
import xarray as xr
import napari

from gulp2p.preproc import utils, imaging
from gulp2p.preproc.tiff import Tiff
from gulp2p.preproc.trial import Trial

from gulp2p.config import CONFIG_DICT

# %% [markdown]
# ### Logging config

# %%
log_level = logging.INFO    # log levels: DEBUG, INFO, WARNING, ERROR, CRITICAL
log_format = "{asctime} - {levelname} - {name} - [{filename} {funcName}() {lineno}] - {message}"
logging.basicConfig(format=log_format, level=log_level, style="{") 

logging.getLogger("gulp2p").setLevel(logging.DEBUG)

# %% [markdown]
# ## Select Data

# %%
# tiff_path = utils.select_file_path(initialdir=Path(r"Z:\2PImaging\Kerstin\MIMS"))

tiff_path = Path(r'Z:\2PImaging\Cole\20241015\1040\1040nm_3x_30slice_60pctpwr_LexA-PFL_GCaMP6_DNa02-JRG_00001.tif')

print(tiff_path)
# Out:
# Z:\2PImaging\Cole\20241015\1040\1040nm_3x_30slice_60pctpwr_LexA-PFL_GCaMP6_DNa02-JRG_00001.tif

# %% [markdown]
# ## Tiff

# %%
# Create Tiff object
# tiff = Tiff(tiff_path)

# %%
# tiff.is_scanimage

# %%
# tiff.stack.dims

# %%
# type(tiff.stack.sizes)

# %%
# viewer = napari.Viewer()



# viewer.add_image(tiff.stack,
#                  colormap=CONFIG_DICT['napari_colormap'],
#                  gamma=CONFIG_DICT['napari_gamma'],
#                  name="full_stack",
#                  axis_labels=tiff.stack.dims)

# viewer.dims.axis_labels = tiff.stack.dims

# z_mip = tiff.stack.max(dim='Z')
# viewer.add_image(z_mip,
#                  colormap=CONFIG_DICT['napari_colormap'],
#                  gamma=CONFIG_DICT['napari_gamma'],
#                  name='z_mip_stack',
#                  axis_labels=z_mip.dims)


# napari.run()

# %% [markdown]
# ## Process

# %%
imaging.process_all([tiff_path], save=True, skip=False, use_full_volume=True, with_bhv=False)
# Out:
# 2024-12-06 15:40:08,275 - INFO - gulp2p.preproc.imaging - [imaging.py preprocess() 599] - Processing Z:\2PImaging\Cole\20241015\1040\1040nm_3x_30slice_60pctpwr_LexA-PFL_GCaMP6_DNa02-JRG_00001.tif
# 2024-12-06 15:40:08,276 - DEBUG - gulp2p.preproc.tiff - [imaging.py preprocess() 603] - tiff object created: Z:\2PImaging\Cole\20241015\1040\1040nm_3x_30slice_60pctpwr_LexA-PFL_GCaMP6_DNa02-JRG_00001.tif
# 2024-12-06 15:40:08,277 - INFO - gulp2p.preproc.tiff - [tiff.py load_stack() 326] - loading tiff stack
# 2024-12-06 15:40:10,375 - DEBUG - gulp2p.preproc.tiff - [tiff.py load_stack() 360] - Tiff shape: (100, 30, 2, 512, 512)
# 2024-12-06 15:40:10,376 - DEBUG - gulp2p.preproc.tiff - [tiff.py load_stack() 364] - z_coords: [275.588, 281.603, 287.617, 293.631, 299.645, 305.66, 311.674, 317.688, 323.702, 329.717, 335.731, 341.745, 347.759, 353.774, 359.788, 365.802, 371.816, 377.831, 383.845, 389.859, 395.873, 401.888, 407.902, 413.916, 419.93, 425.945, 431.959, 437.973, 443.987, 450.002]
# ...
